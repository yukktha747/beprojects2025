# %% [markdown]
# # AI Driven Crop Disease Prediction and Management System ResNet50

# %% [markdown]
# ## CSPW007

# %%
#IMPORTING LIBRARIES
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem Statement
#
# - Utilize AI to predict crop diseases at an early stage, enabling timely intervention and minimizing crop loss.
# - Implement sensors and data analytics to assess soil conditions and provide recommendations for optimal crop growth.
# - Use AI to optimize pesticide application and irrigation, reducing waste and promoting sustainable farming.
# - Integrate environmental data and predictive models to enhance crop management, prevent disease outbreaks, and improve overall yield.

# %%
path='./Dataset/train'
plt.figure(figsize=(70,70))
count=0
plant_names=[]
total_images=0
for i in os.listdir(path):
  count+=1
  plant_names.append(i)
  plt.subplot(7,7,count)

  images_path=os.listdir(path+"/"+i)
  print("Number of images of "+i+":",len(images_path),"||",end=" ")
  total_images+=len(images_path)

  image_show=plt.imread(path+"/"+i+"/"+images_path[0])
  
  plt.imshow(image_show)
  plt.xlabel(i)
  
  plt.xticks([])
  plt.yticks([])


print("Total number of images we have",total_images)
# Out:
# Number of images of Potato___Early_blight: 1939 || Number of images of Potato___healthy: 1824 || Number of images of Potato___Late_blight: 1939 || Total number of images we have 5702

# %%
print(plant_names)
print(len(plant_names))
# Out:
# ['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']
# 3

# %% [markdown]
# **IMPORTING NECESSARY LIBRARIES FOR TRAINING OF MODEL**

# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential,load_model,Model
from keras.layers import Conv2D,MaxPool2D,AveragePooling2D,Dense,Flatten,ZeroPadding2D,BatchNormalization,Activation,Add,Input,Dropout,GlobalAveragePooling2D
from keras.optimizers import SGD
from keras.initializers import glorot_uniform
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau

# %% [markdown]
# # RESNET50 IMPLEMENTATION USING KERAS API

# %% [markdown]
# **WHAT IS RENSET MODEL?**

# %% [markdown]
# ## ResNet-50
#
# -  ResNet-50 is a 50-layer deep convolutional neural network (CNN) used for image classification and feature extraction.
# -  Utilizes residual connections (skip connections) to mitigate vanishing gradient problems and enable training of very deep networks.
# -  Composed of convolutional layers, batch normalization, ReLU activation, and identity/shortcut connections.
# - Extracts hierarchical features from images, making it useful for applications like object detection and medical diagnosis.
# -  Available in deep learning frameworks like TensorFlow and PyTorch, often pre-trained on ImageNet for transfer learning.
# -  Balances depth and computational efficiency, making it suitable for real-world applications including crop disease identification.

# %% [markdown]
# **WHY RESNET?**

# %% [markdown]
# ## Why Use ResNet-50?
#
# -  Provides high accuracy in image classification tasks, improving disease detection reliability.
# -  Residual learning allows training of deeper networks without suffering from vanishing gradients.
# - Allows transfer learning, reducing the need for large labeled datasets and speeding up training.
# - Captures intricate patterns and textures in plant images, making it effective for crop disease identification.
# - Can be fine-tuned and adapted to different crop diseases, improving model flexibility and performance.

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

# %%
base_model_tf=ResNet50(include_top=False,weights='imagenet',input_shape=(224,224,3),classes=38)

# %%
#Model building
base_model_tf.trainable=False

pt=Input(shape=(224,224,3))
func=tensorflow.cast(pt,tensorflow.float32)
x=preprocess_input(func) #This function used to zero-center each color channel wrt Imagenet dataset
model_resnet=base_model_tf(x,training=False)
model_resnet=GlobalAveragePooling2D()(model_resnet)
model_resnet=Dense(128,activation='relu')(model_resnet)
model_resnet=Dense(64,activation='relu')(model_resnet)
model_resnet=Dense(3,activation='softmax')(model_resnet)


model_main=Model(inputs=pt,outputs=model_resnet)
model_main.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.cast (TFOpLambda)        (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 23,858,435
# Trainable params: 270,723
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
#Image augmentation
train_datagen= ImageDataGenerator(shear_range=0.2,zoom_range=0.2,horizontal_flip=False,vertical_flip=False
                                  ,fill_mode='nearest',width_shift_range=0.2,height_shift_range=0.2)

val_datagen=ImageDataGenerator()

path_train='./Dataset/train'

path_valid='./Dataset/valid'

train= train_datagen.flow_from_directory(directory=path_train,batch_size=32,target_size=(224,224),
                                         color_mode='rgb',class_mode='categorical',seed=42)

valid=val_datagen.flow_from_directory(directory=path_valid,batch_size=32,target_size=(224,224),color_mode='rgb',class_mode='categorical')
# Out:
# Found 5702 images belonging to 3 classes.
# Found 1426 images belonging to 3 classes.

# %%
#CallBacks
import os
os.makedirs("./checkpoints", exist_ok=True)

es=EarlyStopping(monitor='val_accuracy',verbose=1,patience=7,mode='auto')
mc=ModelCheckpoint(filepath='./checkpoints/model.h5', monitor='val_accuracy', verbose=1, save_best_only=True)
lr=ReduceLROnPlateau(monitor='val_accuracy',verbose=1,patience=5,min_lr=0.001)

# %%
model_main.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
#Training
model_main.fit(train,validation_data=valid,epochs=30,verbose=1,callbacks=[mc,es,lr])
# Out:
# Epoch 1/30
# 179/179 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9569
# Epoch 1: val_accuracy improved from -inf to 0.98317, saving model to ./checkpoints\model.h5
# 179/179 [==============================] - 69s 346ms/step - loss: 0.1044 - accuracy: 0.9569 - val_loss: 0.0408 - val_accuracy: 0.9832 - lr: 0.0010
# Epoch 2/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9900
# Epoch 2: val_accuracy improved from 0.98317 to 0.99439, saving model to ./checkpoints\model.h5
# 179/179 [==============================] - 57s 317ms/step - loss: 0.0273 - accuracy: 0.9900 - val_loss: 0.0171 - val_accuracy: 0.9944 - lr: 0.0010
# Epoch 3/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9925
# Epoch 3: val_accuracy improved from 0.99439 to 0.99579, saving model to ./checkpoints\model.h5
# 179/179 [==============================] - 58s 325ms/step - loss: 0.0241 - accuracy: 0.9925 - val_loss: 0.0103 - val_accuracy: 0.9958 - lr: 0.0010
# Epoch 4/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9891
# Epoch 4: val_accuracy improved from 0.99579 to 0.99719, saving model to ./checkpoints\model.h5
# 179/179 [==============================] - 61s 343ms/step - loss: 0.0309 - accuracy: 0.9891 - val_loss: 0.0079 - val_accuracy: 0.9972 - lr: 0.0010
# Epoch 5/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9928
# Epoch 5: val_accuracy did not improve from 0.99719
# 179/179 [==============================] - 58s 322ms/step - loss: 0.0208 - accuracy: 0.9928 - val_loss: 0.0122 - val_accuracy: 0.9958 - lr: 0.0010
# Epoch 6/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9947
# Epoch 6: val_accuracy did not improve from 0.99719
# 179/179 [==============================] - 60s 336ms/step - loss: 0.0138 - accuracy: 0.9947 - val_loss: 0.0132 - val_accuracy: 0.9944 - lr: 0.0010
# Epoch 7/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9940
# Epoch 7: val_accuracy did not improve from 0.99719
# 179/179 [==============================] - 66s 371ms/step - loss: 0.0152 - accuracy: 0.9940 - val_loss: 0.0062 - val_accuracy: 0.9972 - lr: 0.0010
# Epoch 8/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9911
# Epoch 8: val_accuracy did not improve from 0.99719
# 179/179 [==============================] - 66s 367ms/step - loss: 0.0258 - accuracy: 0.9911 - val_loss: 0.0287 - val_accuracy: 0.9909 - lr: 0.0010
# Epoch 9/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9965
# Epoch 9: val_accuracy did not improve from 0.99719
# 179/179 [==============================] - 61s 341ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 0.0107 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 10/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9967
# Epoch 10: val_accuracy did not improve from 0.99719
# 179/179 [==============================] - 69s 384ms/step - loss: 0.0100 - accuracy: 0.9967 - val_loss: 0.0161 - val_accuracy: 0.9951 - lr: 0.0010
# Epoch 11/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9977
# Epoch 11: val_accuracy improved from 0.99719 to 0.99790, saving model to ./checkpoints\model.h5
# 179/179 [==============================] - 67s 373ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.0052 - val_accuracy: 0.9979 - lr: 0.0010
# Epoch 12/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9977
# Epoch 12: val_accuracy did not improve from 0.99790
# 179/179 [==============================] - 65s 360ms/step - loss: 0.0092 - accuracy: 0.9977 - val_loss: 0.0071 - val_accuracy: 0.9979 - lr: 0.0010
# Epoch 13/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9944
# Epoch 13: val_accuracy did not improve from 0.99790
# 179/179 [==============================] - 64s 360ms/step - loss: 0.0161 - accuracy: 0.9944 - val_loss: 0.0329 - val_accuracy: 0.9923 - lr: 0.0010
# Epoch 14/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9963
# Epoch 14: val_accuracy did not improve from 0.99790
# 179/179 [==============================] - 59s 331ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0099 - val_accuracy: 0.9958 - lr: 0.0010
# Epoch 15/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9967
# Epoch 15: val_accuracy improved from 0.99790 to 0.99930, saving model to ./checkpoints\model.h5
# 179/179 [==============================] - 58s 326ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.0033 - val_accuracy: 0.9993 - lr: 0.0010
# Epoch 16/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9961
# Epoch 16: val_accuracy did not improve from 0.99930
# 179/179 [==============================] - 59s 330ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.0065 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 17/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9953
# Epoch 17: val_accuracy did not improve from 0.99930
# 179/179 [==============================] - 60s 336ms/step - loss: 0.0137 - accuracy: 0.9953 - val_loss: 0.0073 - val_accuracy: 0.9972 - lr: 0.0010
# Epoch 18/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9972
# Epoch 18: val_accuracy did not improve from 0.99930
# 179/179 [==============================] - 63s 351ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.0117 - val_accuracy: 0.9951 - lr: 0.0010
# Epoch 19/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9986
# Epoch 19: val_accuracy did not improve from 0.99930
# 179/179 [==============================] - 61s 341ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.0067 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 20/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9963
# Epoch 20: val_accuracy did not improve from 0.99930
# 179/179 [==============================] - 61s 339ms/step - loss: 0.0128 - accuracy: 0.9963 - val_loss: 0.0122 - val_accuracy: 0.9958 - lr: 0.0010
# Epoch 21/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9958
# Epoch 21: val_accuracy did not improve from 0.99930
# 179/179 [==============================] - 63s 351ms/step - loss: 0.0134 - accuracy: 0.9958 - val_loss: 0.0126 - val_accuracy: 0.9951 - lr: 0.0010
# Epoch 22/30
# 179/179 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9967
# Epoch 22: val_accuracy did not improve from 0.99930
# 179/179 [==============================] - 72s 399ms/step - loss: 0.0084 - accuracy: 0.9967 - val_loss: 0.0238 - val_accuracy: 0.9930 - lr: 0.0010
# Epoch 22: early stopping

# %%
model_main.save("RESNET50_PLANT_DISEASE.h5")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
from PIL import Image

# %%
plt.figure(figsize=(10,5))
plt.plot(model_main.history.history['loss'],color='b',label='Training loss')
plt.plot(model_main.history.history['val_loss'],color='r',label='Validation loss')
plt.xlabel("epochs")
plt.ylabel("loss_value")
plt.title("loss")
# Out:
# Text(0.5, 1.0, 'loss')

# %%
plt.figure(figsize=(10,5))
plt.plot(model_main.history.history['accuracy'],color='b',label='Training accuracy')
plt.plot(model_main.history.history['val_accuracy'],color='r',label='Validation accsuracy')
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.title("accuracy graph")
# Out:
# Text(0.5, 1.0, 'accuracy graph')
