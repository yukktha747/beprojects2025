# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.12 MiB | 11.18 MiB/s, done.
# Resolving deltas: 100% (11858/11858), done.

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %%
# %pip install -qr requirements.txt comet_ml
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 713.5/713.5 kB 45.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 51.8 MB/s eta 0:00:00
# ...

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.0/112.6 GB disk)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 50.9ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 31.1ms
# Speed: 0.6ms pre-process, 41.0ms inference, 117.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# %cd ..
# %cd datasets/
# !unzip -q cvl_pcb_dslr_4.zip -d ./ && rm cvl_pcb_dslr_4.zip

# %%
# %cd ..
# %cd yolov5/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_path = "content/drive/MyDrive/Dataset/combined"

# %%
import os
dataset_path = '/content/drive/MyDrive/Dataset/combined'
print(os.listdir(dataset_path))  # To check if the data is correctly loaded
# Out:
# ['images', 'labels', 'data.yaml']

# %%
# # Step 1: Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# # Step 2: Define paths
# zip_path = '/content/drive/MyDrive/Dataset/combined.zip'  # Update this to the path of your ZIP file
# extract_path = '/content/drive/MyDrive/Dataset'  # Define where you want to extract the files

# # Step 3: Unzip the file
# import zipfile
# import os

# # Check if the extraction path exists, if not, create it
# if not os.path.exists(extract_path):
#     os.makedirs(extract_path)

# # Extract the ZIP file
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_path)

# # Step 4: Verify extracted files
# print(os.listdir(extract_path))  # List the contents of the extracted dataset

# %% [markdown]
# # Train

# %%
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 30 --data /content/drive/MyDrive/Dataset/combined/data.yaml --weights yolov5s.pt --device 0
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#       21/29      4.57G    0.03291    0.01743   0.008154         42        640:  22% 60/273 [00:42<01:48,  1.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       21/29      4.57G    0.03291    0.01744    0.00808         53        640:  22% 61/273 [00:44<02:55,  1.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       21/29      4.57G    0.03284    0.01736   0.008158         35        640:  23% 62/273 [00:44<02:23,  1.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %% [markdown]
# # Validate

# %%
# !python /content/yolov5/val.py --img 640 --data /content/drive/MyDrive/Dataset/combined/data.yaml --weights /content/yolov5/runs/train/exp2/weights/best.pt --device 0
# Out:
# val: data=/content/drive/MyDrive/Dataset/combined/data.yaml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7031701 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1C2RMSC7ywKG0WN-_OHSLF-CTWMEVezJ5/Dataset/combined/labels/val.cache... 1038 images, 2 backgrounds, 0 corrupt: 100% 1038/1038 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 33/33 [00:25<00:00,  1.28it/s]
# ...

# %% [markdown]
# # Save the model

# %%
# !cp /content/yolov5/runs/train/exp2/weights/best.pt /content/drive/MyDrive/Dataset/combined_model_best.pt
